# %% [markdown]
# <a href="https://colab.research.google.com/github/hakanmetei/hakanmetei/blob/main/btk_akademi_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #String = bildiğimiz metindir

# %%
"merhaba dünya"
# Out:
# 'merhaba dünya'
